# %% [markdown]
# <a href="https://colab.research.google.com/github/Roksana18cse04/Ml-project/blob/main/voice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydub

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Audio to Text Generation

# %% [markdown]
# load dataset

# %%
from pydub import AudioSegment

# Convert MP3 to WAV
sound = AudioSegment.from_file("/content/WhatsApp Audio 2025-04-15 at 9.22.46 AM.mp4")  # Auto-detect formatsound.export("imtroduceme.wav", format="wav")

sound = AudioSegment.from_file("/content/WhatsApp Audio 2025-04-15 at 9.22.46 AM.mp4", format="mp4")  # Assuming it's actually MP4
sound.export("imtroduceme.wav", format="wav")  # Changed 'formatsound' to 'sound'
# Out:
# <_io.BufferedRandom name='imtroduceme.wav'>

# %%
# !pip install SpeechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 62.7 MB/s eta 0:00:00
# ...

# %%
import speech_recognition as sr

r = sr.Recognizer()
with sr.AudioFile("imtroduceme.wav") as source:  # Use the WAV file
    audio = r.record(source)
text = r.recognize_google(audio, language="eng")
print(text)
# Out:
# hello assalamualaikum my name is Roxanne akhtar I'm thrilled to introduce myself to you today I decided in the car Bangladesh where I have had the pleasure of growing up and partaking in the Bountiful culture of this wonderful setting I am graduate from gopalganj Science and Technology University where I did computer science and engineering go out my study I had a solid background in all the messages like that technology software engineering machine Learning Center and the skill is Xcel power bill by don't that analysis and machine Learning Center I always had a desire to learn and acquire new thing though I am a fresher with no work experience today I have been continuously working No Berries project that have been on my schedule a few them are the Netflix movie theater analysis and the building of cells inside dashboard they have provided me with hands on experience in that analysis and dashboard building Airport from Academy online and maintain a good balance in my personal life I
# ...

# %%
# !pip install googletrans==4.0.0-rc1
# !pip install gTTS
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.3 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=a8e7be23080c32ab805b17c88ce0bc4492d78003ddf6920d0221347b75f03bc9
#   Stored in directory: /root/.cache/pip/wheels/39/17/6f/66a045ea3d168826074691b4b787b8f324d3f646d755443fda
# Successfully built googletrans
# ...
#   Attempting uninstall: hyperframe
# ...

# %%
from googletrans import Translator

translator = Translator()
translated = translator.translate(text, dest='bn')  # 'fr' for French, change as needed
print(translated.text)
# Out:
# হ্যালো অ্যাসালামুয়ালাইকুম আমার নাম রোকসান আখতার আমি আজ আপনার সাথে নিজেকে পরিচয় করিয়ে দিতে পেরে রোমাঞ্চিত আমি এই গাড়িটি বাংলানজ সায়েন্স এবং টেকনোলজি ইউনিভার্সিটি থেকে গ্র্যাজারিং ওয়ানডায়নের মতো গ্র্যাজুয়েট পেয়েছি যেখানে আমার কাছে কম্পিউটার বিজ্ঞান এবং ইঞ্জিনিয়ারিংয়ে আমি একটি সলিউট করেছি, যেখানে আমি এই জপস ওয়েলিং করেছি যেখানে আমি এই দুর্দান্তভাবে রয়েছি এবং এই প্রযুক্তিগতভাবে আমি এই দুর্দান্তভাবে পড়াশোনা করেছি যেখানে আমি জোপালগানজ বিজ্ঞান এবং প্রযুক্তি থেকে স্নাতক হয়েছি এবং এই প্রযুক্তিগুলি পেয়েছি যে আমি জোপালগানজ বিজ্ঞান এবং ইঞ্জিনিয়ারিংয়ের মাধ্যমে স্নাতক হয়েছি এবং আমি যে প্রযুক্তিগুলি দিয়েছি তা আমি জোপালগানজ বিজ্ঞান এবং ইঞ্জিনিয়ারিং করেছি।মেশিন লার্নিং সেন্টার আমি সর্বদা নতুন জিনিস শিখতে এবং অর্জন করার ইচ্ছা পোষণ করি যদিও আমি আজ কোনও কাজের অভিজ্ঞতা ছাড়াই নতুন কিছু হয়ে থাকি না আমি ক্রমাগত কোনও বেরি প্রকল্প কাজ করে যাচ্ছি যা আমার সময়সূচীতে ছিল তাদের কয়েকটি হ'ল নেটফ্লিক্স মুভি থিয়েটার বিশ্লেষণ এবং ড্যাশবোর্ডের অভ্যন্তরীণ কোষগুলির বিল্ডিং যা তারা আমাকে বিশ্লেষণ এ
# ...

# %%
from gtts import gTTS

tts = gTTS(text=translated.text, lang='bn')  # 'fr' for French, change as needed
tts.save("translated_audio.mp3")

# %%
# Sentiment Analysis
from textblob import TextBlob

blob = TextBlob(text)
sentiment = blob.sentiment.polarity

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
nltk.download('punkt_tab')


tokens = word_tokenize(text)
freq_dist = FreqDist(tokens)

print(freq_dist.most_common(10))
# Out:
# [('and', 11), ('I', 10), ('to', 10), ('my', 6), ('of', 6), ('the', 5), ('a', 5), ('am', 4), ('for', 4), ('is', 3)]
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Sentiment Analysis
from textblob import TextBlob

blob = TextBlob(text)
sentiment = blob.sentiment.polarity
sentiment
# Out:
# 0.19909812409812408

# %%
sentiment_label = "positive" if sentiment > 0 else "negative" if sentiment < 0 else "neutral"
sentiment_label
# Out:
# 'positive'

# %% [markdown]
# Sentiment Analysis

# %%
text ="hey gemini I  am sad cause  someone break my heart "
tokens = word_tokenize(text)
freq_dist = FreqDist(tokens)
print(freq_dist.most_common(10))
# Out:
# [('hey', 1), ('gemini', 1), ('I', 1), ('am', 1), ('sad', 1), ('cause', 1), ('someone', 1), ('break', 1), ('my', 1), ('heart', 1)]

# %%
# Sentiment Analysis
from textblob import TextBlob

blob = TextBlob(text)
sentiment = blob.sentiment.polarity
sentiment
# Out:
# -0.5

# %%
sentiment_label = "positive" if sentiment > 0 else "negative" if sentiment < 0 else "neutral"
sentiment_label
# Out:
# 'negative'

# %% [markdown]
# Text Translation

# %%
from googletrans import Translator

# %%
translator = Translator()

# %%
translated = translator.translate(text, dest='bn') # bn for Bengali
print(translated.text)
# Out:
# আরে জেমিনি আমি দু: খিত কারণ কেউ আমার হৃদয় ভেঙে দেয়

# %%
import nltk
from transformers import pipeline

# %% [markdown]
# Text Summarization

# %%
summarizer = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ...

# %%
summary = summarizer(text, max_length=130, min_length=30, do_sample=False)
print(summary[0]['summary_text'])
# Out:
#  Roxana akhtar is currently residing in Dhaka Bangladesh where I have been for tonight enough to grow up and what is the release culture of this great City for studies .

# %% [markdown]
# Answering Question

# %%
qa_model = pipeline("question-answering", model="distilbert-base-cased-distilled-squad")
# Out:
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Device set to use cpu

# %%
context = "my name is Roxana akhtar. I am so happy to be introducing myself to you today .I am currently residing in Dhaka Bangladesh. where I have been for tonight enough to grow up and what is the release culture of this great City for studies .I was admitted to Gopalganj Science and Technology University ,where I started computer science and engineering during my study period. I developed a strong foundation in a number of the major subjects such as technology machine Learning Center and my skin is Excel for that analysis and machine learning my passion for learning has analysis has driven me to pressure new knowledge and experience though I am fresh experience yet I have worked on some project that helped me develop my schedule some of the project include Netflix Netflix in my personal life I am fortunate to have a supportive family and a kind of group of friends home motivated and inspired Middle Eastern hang out together exploring new location and making life long memories I appreciate you willing to take the time to learn a little about me see the opportunity to talk with each of you and to share future inside regarding our experience and depression"

# %%
question = "Who persion name This text"

# %%
result = qa_model(question=question, context=context)
print(result['answer'])
# Out:
# Roxana akhtar

# %%
question="Roksana is from where?"
result = qa_model(question=question, context=context)
print(result['answer'])
# Out:
# Dhaka Bangladesh

# %%
question = " Roxana akther is University Name?"
result = qa_model(question=question, context=context)
print(result['answer'])
# Out:
# assalamualaikum

# %%
qa_model = pipeline("question-answering", model="distilbert-base-cased-distilled-squad")
# Out:
# Device set to use cpu

# %%
question = "What is Roxana Akter's university name?"

# %%
result = qa_model(question=question, context=context)
print(result['answer'])
# Out:
# Roxana akhtar
